# %% [markdown]
# ### Chapter 4 Coding Problem
#
# # Directions
#     - Implement batch gradient descent with early stopping for softmax regression without using Sk-Learn, only using Numpy. Use it on a classification task such as the iris dataset
