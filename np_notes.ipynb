# %% [markdown]
# ### Numpy Notes
# - This file offers a way of learning numpy through experimentation and practical coding experience.
#     + Identify what the documentation has described the function or feature
#     + Understand and play with the parameters
#     + Code with several examples and test the behavior

# %%
import numpy as np
# Out:
# Hello, World!

# %% [markdown]
# ## linespace

# %%
example_linespace = np.linspace(0, 10, 3)
print(ex_linespace)
# includes the starting and ending values
# The function generates 10 evenly spaced values between 0 and 10
# np.linespace(start, end, number of values)
# Out:
# [ 0.  5. 10.]
